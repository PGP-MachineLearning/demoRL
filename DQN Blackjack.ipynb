# %% [markdown]
# #Demo de TF-Agents para BlackJac (21) usando DQN basado en los tutoriales de Tensor Flow:
#
# Fuente: https://www.tensorflow.org/agents/tutorials/2_environments_tutorial

# %% [markdown]
# 0) Preparar el ambiente:

# %%
#@title Instalar Paquete de TF-Agents
# !pip install -q tf-agents
print("TF-Agentes instalado.")
# Out:
# TF-Agentes instalado.

# %%
#@title Cargar Librerías
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import abc
import tensorflow as tf
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from random import randint

from tf_agents.environments import py_environment
from tf_agents.environments import tf_py_environment

from tf_agents.environments import utils
from tf_agents.specs import array_spec

from tf_agents.policies import random_tf_policy

from tf_agents.trajectories import time_step as ts

from tf_agents.agents.dqn import dqn_agent
from tf_agents.networks import q_network
from tf_agents.utils import common

from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.trajectories import trajectory

tf.compat.v1.enable_v2_behavior()

print("Librerías cargadas.")
# Out:
# Librerías cargadas.

# %% [markdown]
# 1) Establecer las clases del Problema y del Agente:

# %%
#@title Definir Entorno del Problema 

# Un entorno que represente el juego podría verse así:
##Acciones: Tenemos 2 acciones. 
##             Acción 0: obtener una nueva carta 
##             Acción 1: terminar la ronda actual.
##Observaciones: Suma de las cartas de la ronda actual.
##Recompensa: El objetivo es acercarse lo más posible a 21 sin pasarse, 
##            por lo que podemos lograrlo usando la siguiente recompensa al final de la ronda: 
##            suma_de_tarjetas - 21 si suma_de_tarjetas <= 21, de lo contrario -21
class CardGameEnv(py_environment.PyEnvironment):

  def __init__(self):
    self._action_spec = array_spec.BoundedArraySpec(
        shape=(), dtype=np.int32, minimum=0, maximum=1, name='action')
    self._observation_spec = array_spec.BoundedArraySpec(
        shape=(2,), dtype=np.int32, minimum=0, name='observation')
    self._state = 0
    self._episode_ended = False

  def action_spec(self):
    # devuelve la forma de las acciones
    return self._action_spec

  def observation_spec(self):
    # devuelve la forma de las observaciones   
    return self._observation_spec

  def _reset(self):
    # resetea el entorno
    self._state = 0
    self._episode_ended = False
    return ts.restart(np.array([self._state, 0], dtype=np.int32))

  def _step(self, action):
    # aplica una acción sobre el entorno
    
    if self._episode_ended:
      # si el entorno está finalizado, lo resetea
      return self.reset()

    # Aplica la acción
    if action == 1:
      # indica no seguir jugando
      self._episode_ended = True
      new_card = 0
    elif action == 0:
      # solicita una carta
      new_card = randint(1, 12)
      if new_card == 1:
        # el as puede valer 1 o 11
        if (self._state + 11) < 21:
          self._state = self._state + 11
        else:
          self._state = self._state + 1  
      elif new_card >= 10:
        # las figuras valen 10
        self._state = self._state + 10
      else:
        # el resto vale su valor
        self._state = self._state + new_card
    else:
      raise ValueError('La acción debe ser 0 o 1.')

    # finaliza si se indica no seguir jugando o se llega a un valor de 17 (no se puede pedir más)
    if self._episode_ended or self._state >= 17:
      # si finaliza
      # determina el reward (siempre se maximiza)
      # en este caso el máximo es 21!
      if self._state > 21:
        # se paso de 21, devuelve cantidad que se paso (negativo)
        reward = 21 - self._state 
      else:
        # no se paso de 21 (devuelve a donde llegó)
        reward = self._state 
      return ts.termination(np.array([self._state, new_card], dtype=np.int32), reward)
    else:
      # si no finaliza
      return ts.transition(
          np.array([self._state, new_card], dtype=np.int32), reward=0.0, discount=1.0)


print("Entorno del Problema definido.")

# Definir entornos de entrenamiento y evaluación
train_py_env = CardGameEnv()
eval_py_env = CardGameEnv()

# Definir wrapper para convertir en entornos TF
train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# define política al azar independiente del Agente
random_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(),
                                                train_env.action_spec())

print("Entornos de entrenamiento y prueba definidos. ")


# definir simulador para probar el entorno
def SimularEntorno(eval_env, policy, titulo, num_episodes=1):
    if num_episodes <=0:
      num_episodes = 1    
    # inicializa acumulador auxiliar 
    cumulative_reward_total = 0.0    
    print("\n** ", titulo, "**")                   
    for i in range(num_episodes):
      if num_episodes>1:
        print("\n> Episodio ", i+1, ": ")
      # muesta estado inicial
      time_step = eval_env.reset()  
      ob = time_step.observation.numpy()[0]
      print(" Ini: estado ", ob[0], "[", time_step, "]")      
      j = 1
      while not time_step.is_last():
        # la política determina la acción a realizar
        action_step = policy.action(time_step)
        time_step = eval_env.step(action_step.action)
        # recupera la observación y muestra el nuevo estado 
        ob = time_step.observation.numpy()[0]
        if ob[1] == 0:
          descAccion = "decide no pedir más cartas"
        else:
          descAccion = "sale carta " + str( ob[1] )
        print(" #", j, ": ", descAccion, "-> estado ", ob[0], "[", time_step, "]")
        j = j + 1
        
      # muestra estado final
      ob = time_step.observation.numpy()[0]
      r = time_step.reward.numpy()
      print(" Fin -> estado ", ob[0], "[", time_step, "]")
      print(' Recompensa final = ', r[0])
      cumulative_reward_total += r[0]
    if num_episodes > 1:
      promedioEpisodios = round(cumulative_reward_total/num_episodes,3)
      print("\n= Recompensa Promedio Total: ", promedioEpisodios, "\n")
      return promedioEpisodios
    else:
      return cumulative_reward_total

print("Simulador del entorno definido.")

# Probar el entorno definido con Política Aleatoria (opcional)
Probar_Entorno = True #@param {type:"boolean"}

if Probar_Entorno:
  SimularEntorno(eval_env, random_policy, "Probando el entorno del problema al azar")
# Out:
# Entorno del Problema definido.
# Entornos de entrenamiento y prueba definidos.
# Simulador del entorno definido.
#
# **  Probando el entorno del problema al azar **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  decide no pedir más cartas -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Fin -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Recompensa final =  0.0

# %%
#@title Definir el Agente tipo DQN

learning_rate = 1e-3  # @param {type:"number"}
cant_neuronas_ocultas = 100 # @param {type:"integer"}
if cant_neuronas_ocultas < 10:
  cant_neuronas_ocultas = 10

# Define cantidad de neuronas ocultas para RNA-Q
fc_layer_params = (cant_neuronas_ocultas,)

# Define RNA-Q
q_net = q_network.QNetwork(
    train_env.observation_spec(),
    train_env.action_spec(),
    fc_layer_params=fc_layer_params)

optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)

train_step_counter = tf.Variable(0)

# Define el agente de tipo Q
ag = dqn_agent.DqnAgent(
    train_env.time_step_spec(),
    train_env.action_spec(),
    q_network=q_net,
    optimizer=optimizer,
    td_errors_loss_fn=common.element_wise_squared_loss,
    train_step_counter=train_step_counter)

ag.initialize()

# define política para evaluación para el Agente
eval_policy = ag.policy

# define política para recolección de datos para el Agente
collect_policy = ag.collect_policy

print("Agente DQN inicializado. ")
# Out:
# Agente DQN inicializado.

# %%
#@title Definir Métricas para evaluación

# Se usa el promedio de la recompensa (la más común)
# See also the metrics module for standard implementations of different metrics.
# https://github.com/tensorflow/agents/tree/master/tf_agents/metrics

def compute_avg_return(environment, policy, num_episodes=10):

  total_return = 0.0
  for _ in range(num_episodes):

    time_step = environment.reset()
    episode_return = 0.0

    while not time_step.is_last():
      action_step = policy.action(time_step)
      time_step = environment.step(action_step.action)
      episode_return += time_step.reward
    total_return += episode_return

  avg_return = total_return / num_episodes
  return avg_return.numpy()[0]

print("Métricas definidas.")
# Out:
# Métricas definidas.

# %% [markdown]
# 3) Llevar a cabo el Entrenamiento:

# %%
#@title Preparar datos para Entrenamiento

initial_collect_steps = 500  # @param {type:"integer"} 
collect_steps_per_iteration = 1  # @param {type:"integer"}
replay_buffer_max_length = 100000  # @param {type:"integer"}
batch_size = 64  # @param {type:"integer"}


# Define 'Replay Buffer' para que el agente recuerde las observaciones realizadas
replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec = ag.collect_data_spec,
    batch_size = train_env.batch_size,
    max_length = replay_buffer_max_length)

# Recolecta datos generados al azar
# This loop is so common in RL, that we provide standard implementations. 
# For more details see the drivers module.
# https://www.tensorflow.org/agents/api_docs/python/tf_agents/drivers

def collect_step(environment, policy, buffer):
  time_step = environment.current_time_step()
  action_step = policy.action(time_step)
  next_time_step = environment.step(action_step.action)
  traj = trajectory.from_transition(time_step, action_step, next_time_step)

  # Add trajectory to the replay buffer
  buffer.add_batch(traj)

def collect_data(env, policy, buffer, steps):
  for _ in range(steps):
    collect_step(env, policy, buffer)

collect_data(train_env, random_policy, replay_buffer, initial_collect_steps)

print("\nDatos recolectados.")

# Muestra ejemplo de los datos recolectados
##iter(replay_buffer.as_dataset()).next()

# Preparar los datos recolectados con trajectories de shape [Bx2x...]
dataset = replay_buffer.as_dataset(
    num_parallel_calls=3, 
    sample_batch_size=batch_size, 
    num_steps=2).prefetch(3)
iterator = iter(dataset)
# Muestra ejemplo 
##iterator.next()
print("\nDataset creado.")
# Out:
# Datos recolectados.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/autograph/operators/control_flow.py:1218: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.
#
# Dataset creado.

# %%
#@title Entrenar al Agente

cant_ciclos_entrenamiento = 25000 # @param {type:"integer"}
log_cada_ciclos = 200  # @param {type:"integer"}
evaluar_cada_ciclos = 1000  # @param {type:"integer"}
cant_episodios_evaluacion = 25  # @param {type:"integer"}


#  Optimize by wrapping some of the code in a graph using TF function (Optional)
ag.train = common.function(ag.train)

# Reset the train step
ag.train_step_counter.assign(0)

# Evaluate the agent's policy once before training.
avg_return = compute_avg_return(eval_env, ag.policy, cant_episodios_evaluacion)
ar_ciclo = []
ar_returns = []
ar_loss = []

print("\n** Comienza el Entrenamiento **\n")
for _ in range(cant_ciclos_entrenamiento):

  # Collect a few steps using collect_policy and save to the replay buffer.
  collect_data(train_env, ag.collect_policy, replay_buffer, collect_steps_per_iteration)

  # Sample a batch of data from the buffer and update the agent's network.
  experience, unused_info = next(iterator)
  train_loss = ag.train(experience).loss

  step = ag.train_step_counter.numpy()

  if (step == 1) or (step % log_cada_ciclos == 0):
    print('step = {0}: loss = {1:.3f}'.format(step, train_loss))    
    ar_ciclo.append( step )
    ar_loss.append( train_loss )
    avg_return = compute_avg_return(eval_env, ag.policy, cant_episodios_evaluacion)
    ar_returns.append( avg_return )

    if (step == 1) or (step % evaluar_cada_ciclos == 0):
      print('step = {0}: Promedio Recompensa = {1:.1f}'.format(step, avg_return))

print("\n** Entrenamiento Finalizado **\n")
# Out:
# ** Comienza el Entrenamiento **
#
# step = 1: loss = 0.894
# step = 1: Promedio Recompensa = 15.0
# step = 200: loss = 2.629
# step = 400: loss = 8.291
# step = 600: loss = 2.720
# step = 800: loss = 6.244
# step = 1000: loss = 6.141
# step = 1000: Promedio Recompensa = 17.1
# step = 1200: loss = 2.884
# step = 1400: loss = 4.382
# step = 1600: loss = 1.783
# step = 1800: loss = 6.612
# step = 2000: loss = 4.785
# step = 2000: Promedio Recompensa = 16.3
# step = 2200: loss = 0.895
# step = 2400: loss = 8.966
# step = 2600: loss = 8.042
# step = 2800: loss = 5.654
# step = 3000: loss = 10.397
# step = 3000: Promedio Recompensa = 15.0
# step = 3200: loss = 3.105
# step = 3400: loss = 2.429
# step = 3600: loss = 2.162
# step = 3800: loss = 8.031
# step = 4000: loss = 1.017
# step = 4000: Promedio Recompensa = 15.8
# step = 4200: loss = 7.866
# step = 4400: loss = 2.081
# step = 4600: loss = 2.065
# step = 4800: loss = 5.627
# step = 5000: loss = 1.591
# step = 5000: Promedio Recompensa = 15.7
# step = 5200: loss = 5.618
# step = 5400: loss = 7.473
# step = 5600: loss = 9.091
# step = 5800: loss = 1.564
# step = 6000: loss = 7.052
# step = 6000: Promedio Recompensa = 15.5
# step = 6200: loss = 2.859
# step = 6400: loss = 4.783
# step = 6600: loss = 3.649
# step = 6800: loss = 3.095
# step = 7000: loss = 4.348
# step = 7000: Promedio Recompensa = 15.3
# step = 7200: loss = 6.753
# step = 7400: loss = 4.993
# step = 7600: loss = 4.204
# step = 7800: loss = 4.659
# step = 8000: loss = 2.361
# step = 8000: Promedio Recompensa = 17.0
# step = 8200: loss = 4.435
# step = 8400: loss = 5.685
# step = 8600: loss = 5.397
# step = 8800: loss = 6.164
# step = 9000: loss = 1.627
# step = 9000: Promedio Recompensa = 15.8
# step = 9200: loss = 1.044
# step = 9400: loss = 8.951
# step = 9600: loss = 1.837
# step = 9800: loss = 10.972
# step = 10000: loss = 2.885
# step = 10000: Promedio Recompensa = 16.1
# step = 10200: loss = 5.188
# step = 10400: loss = 0.712
# step = 10600: loss = 1.031
# step = 10800: loss = 2.487
# step = 11000: loss = 2.486
# step = 11000: Promedio Recompensa = 15.9
# step = 11200: loss = 2.328
# step = 11400: loss = 0.751
# step = 11600: loss = 1.943
# step = 11800: loss = 5.421
# step = 12000: loss = 4.863
# step = 12000: Promedio Recompensa = 16.6
# step = 12200: loss = 4.259
# step = 12400: loss = 3.381
# step = 12600: loss = 10.157
# step = 12800: loss = 4.248
# step = 13000: loss = 2.698
# step = 13000: Promedio Recompensa = 16.7
# step = 13200: loss = 10.973
# step = 13400: loss = 2.070
# step = 13600: loss = 3.988
# step = 13800: loss = 1.061
# step = 14000: loss = 4.758
# step = 14000: Promedio Recompensa = 13.5
# step = 14200: loss = 5.344
# step = 14400: loss = 10.636
# step = 14600: loss = 8.321
# step = 14800: loss = 1.278
# step = 15000: loss = 1.520
# step = 15000: Promedio Recompensa = 16.2
# step = 15200: loss = 7.023
# step = 15400: loss = 2.818
# step = 15600: loss = 5.261
# step = 15800: loss = 5.184
# step = 16000: loss = 10.914
# step = 16000: Promedio Recompensa = 16.5
# step = 16200: loss = 2.201
# step = 16400: loss = 1.597
# step = 16600: loss = 2.161
# step = 16800: loss = 2.523
# step = 17000: loss = 4.333
# step = 17000: Promedio Recompensa = 16.0
# step = 17200: loss = 4.796
# step = 17400: loss = 2.287
# step = 17600: loss = 6.302
# step = 17800: loss = 4.992
# step = 18000: loss = 1.160
# step = 18000: Promedio Recompensa = 16.5
# step = 18200: loss = 8.372
# step = 18400: loss = 5.375
# step = 18600: loss = 6.503
# step = 18800: loss = 2.727
# step = 19000: loss = 2.147
# step = 19000: Promedio Recompensa = 15.5
# step = 19200: loss = 5.929
# step = 19400: loss = 6.529
# step = 19600: loss = 3.454
# step = 19800: loss = 8.172
# step = 20000: loss = 4.644
# step = 20000: Promedio Recompensa = 15.3
# step = 20200: loss = 1.371
# step = 20400: loss = 2.771
# step = 20600: loss = 5.183
# step = 20800: loss = 10.167
# step = 21000: loss = 5.008
# step = 21000: Promedio Recompensa = 15.9
# step = 21200: loss = 8.839
# step = 21400: loss = 6.192
# step = 21600: loss = 1.784
# step = 21800: loss = 2.937
# step = 22000: loss = 3.555
# step = 22000: Promedio Recompensa = 15.6
# step = 22200: loss = 6.490
# step = 22400: loss = 1.764
# step = 22600: loss = 1.927
# step = 22800: loss = 9.079
# step = 23000: loss = 9.304
# step = 23000: Promedio Recompensa = 16.6
# step = 23200: loss = 8.046
# step = 23400: loss = 4.880
# step = 23600: loss = 7.426
# step = 23800: loss = 1.715
# step = 24000: loss = 5.247
# step = 24000: Promedio Recompensa = 15.1
# step = 24200: loss = 4.896
# step = 24400: loss = 1.429
# step = 24600: loss = 4.661
# step = 24800: loss = 4.993
# step = 25000: loss = 8.382
# step = 25000: Promedio Recompensa = 15.2
#
# ** Entrenamiento Finalizado **

# %%
#@title Mostrar Gráficos del Entrenamiento

plt.figure(figsize=(15,8)) 
plt.plot( ar_ciclo, ar_returns)
plt.plot( ar_ciclo, ar_loss )
plt.title("Resultados del Entrenamiento del Agente")
plt.legend(['Promedio Recompensa', 'Loss de Entrenamiento'], loc='upper right')
plt.ylabel('Valor')
plt.xlabel('Ciclo')
plt.xlim(right=max(ar_ciclo))   
##plt.ylim(top=21)    
plt.grid(True)
plt.show()

# %% [markdown]
# 4) Probar entrenamiento comparando resultados:

# %%
#@title Probar el Agente Entrenado contra el Azar
cantidad_partidas_probar = 5 # @param {type:"integer"}
promAzar = 0
promAgente = 0

for i in range(cantidad_partidas_probar):

  print("\n> Partida ", i+1, ":")

  # Probar Aleatorio
  valorAzar = SimularEntorno(eval_env, random_policy, "Resultados Aleatorio", 1) 
  promAzar = promAzar + valorAzar

  # Probar Agente Entrenado
  valorAgente = SimularEntorno(eval_env, ag.policy, "Resultados de Agente Entrenado", 1) 
  promAgente = promAgente + valorAgente

  # Decide Ganador
  if (valorAgente <= 21 and valorAzar < valorAgente) or (valorAzar > 21):
    print("\n--> GANA el Agente Entrenado (", valorAgente,") contra el azar (", valorAzar,")")
  else:
    print("\n--> PIERDE el Agente Entrenado (", valorAgente,") contra el azar (", valorAzar,")")


# Decide Ganador General
if cantidad_partidas_probar > 0:
  promAgente = promAgente / cantidad_partidas_probar
  promAzar = promAzar / cantidad_partidas_probar
  print("\n================================================================================================\n")
  if (promAgente <= 21 and promAzar < promAgente) or (promAzar > 21):
    print("= En promedio GANA el Agente Entrenado (", promAgente,") contra el azar (", promAzar,")")
  else:
    print("= En promedio PIERDE el Agente Entrenado (", promAgente,") contra el azar (", promAzar,")")
  print("\n================================================================================================\n")
# Out:
# > Partida  1 :
#
# **  Resultados Aleatorio **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  decide no pedir más cartas -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Fin -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Recompensa final =  0.0
#
# **  Resultados de Agente Entrenado **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 6 -> estado  6 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[6, 6]], dtype=int32)>) ]
#  # 2 :  sale carta 2 -> estado  8 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[8, 2]], dtype=int32)>) ]
#  # 3 :  sale carta 11 -> estado  18 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([18.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[18, 11]], dtype=int32)>) ]
#  Fin -> estado  18 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([18.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[18, 11]], dtype=int32)>) ]
#  Recompensa final =  18.0
#
# --> GANA el Agente Entrenado ( 18.0 ) contra el azar ( 0.0 )
#
# > Partida  2 :
#
# **  Resultados Aleatorio **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  decide no pedir más cartas -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Fin -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Recompensa final =  0.0
#
# **  Resultados de Agente Entrenado **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 8 -> estado  8 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[8, 8]], dtype=int32)>) ]
#  # 2 :  sale carta 3 -> estado  11 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[11,  3]], dtype=int32)>) ]
#  # 3 :  sale carta 8 -> estado  19 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([19.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[19,  8]], dtype=int32)>) ]
#  Fin -> estado  19 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([19.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[19,  8]], dtype=int32)>) ]
#  Recompensa final =  19.0
#
# --> GANA el Agente Entrenado ( 19.0 ) contra el azar ( 0.0 )
#
# > Partida  3 :
#
# **  Resultados Aleatorio **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  decide no pedir más cartas -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Fin -> estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  Recompensa final =  0.0
#
# **  Resultados de Agente Entrenado **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 9 -> estado  9 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[9, 9]], dtype=int32)>) ]
#  # 2 :  sale carta 9 -> estado  18 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([18.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[18,  9]], dtype=int32)>) ]
#  Fin -> estado  18 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([18.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[18,  9]], dtype=int32)>) ]
#  Recompensa final =  18.0
#
# --> GANA el Agente Entrenado ( 18.0 ) contra el azar ( 0.0 )
#
# > Partida  4 :
#
# **  Resultados Aleatorio **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 7 -> estado  7 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[7, 7]], dtype=int32)>) ]
#  # 2 :  sale carta 3 -> estado  10 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[10,  3]], dtype=int32)>) ]
#  # 3 :  decide no pedir más cartas -> estado  10 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([10.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[10,  0]], dtype=int32)>) ]
#  Fin -> estado  10 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([10.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[10,  0]], dtype=int32)>) ]
#  Recompensa final =  10.0
#
# **  Resultados de Agente Entrenado **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 7 -> estado  7 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[7, 7]], dtype=int32)>) ]
#  # 2 :  sale carta 11 -> estado  17 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([17.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[17, 11]], dtype=int32)>) ]
#  Fin -> estado  17 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([17.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[17, 11]], dtype=int32)>) ]
#  Recompensa final =  17.0
#
# --> GANA el Agente Entrenado ( 17.0 ) contra el azar ( 10.0 )
#
# > Partida  5 :
#
# **  Resultados Aleatorio **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 1 -> estado  11 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[11,  1]], dtype=int32)>) ]
#  # 2 :  decide no pedir más cartas -> estado  11 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([11.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[11,  0]], dtype=int32)>) ]
#  Fin -> estado  11 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([11.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[11,  0]], dtype=int32)>) ]
#  Recompensa final =  11.0
#
# **  Resultados de Agente Entrenado **
#  Ini: estado  0 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([0], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[0, 0]], dtype=int32)>) ]
#  # 1 :  sale carta 5 -> estado  5 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[5, 5]], dtype=int32)>) ]
#  # 2 :  sale carta 1 -> estado  16 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([1], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([1.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[16,  1]], dtype=int32)>) ]
#  # 3 :  decide no pedir más cartas -> estado  16 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([16.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[16,  0]], dtype=int32)>) ]
#  Fin -> estado  16 [ TimeStep(step_type=<tf.Tensor: shape=(1,), dtype=int32, numpy=array([2], dtype=int32)>, reward=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([16.], dtype=float32)>, discount=<tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.], dtype=float32)>, observation=<tf.Tensor: shape=(1, 2), dtype=int32, numpy=array([[16,  0]], dtype=int32)>) ]
#  Recompensa final =  16.0
#
# --> GANA el Agente Entrenado ( 16.0 ) contra el azar ( 11.0 )
#
# ================================================================================================
#
# = En promedio GANA el Agente Entrenado ( 17.6 ) contra el azar ( 4.2 )
#
# ================================================================================================

# %%
#@title Probar Agente Entrenado contra Usuario Humano
import ipywidgets as widgets
from IPython.display import display, clear_output

# define funciones para los botones
def mostrarEstadoFinal(time_step):
  global ValorAgente
  if time_step.is_last():
      # muestra estado final
      ob = time_step.observation.numpy()[0]
      r = time_step.reward.numpy()
      print(" Fin -> estado ", ob[0], "[", time_step, "]")
      print(' Recompensa final = ', r[0])
      if ValorAgente < 0:
        # juega segundo el agente
        ValorAgente = SimularEntorno(eval_env, ag.policy, "Juega el Agente Entrenado", 1) 
      if (ValorAgente <= 21 and r[0] < ValorAgente) or (r[0] > 21):
        print("\n--> GANA el Agente Entrenado (", ValorAgente,") contra el Humano (", r[0],")")
      else:
        print("\n--> PIERDE el Agente Entrenado (", ValorAgente,") contra el Humano (", r[0],")")
      print("\n")          
  return

def on_buttonR_clicked(b):
  global j, ValorAgente, eval_env
  # se toca botón para reiniciar la partida
  with output:
    clear_output()
    print("\n> Nueva Partida:")
    # Determina orden de juego del agente
    ordenAgente = randint(0, 9)
    if ordenAgente < 5:
      # juega primero el agente
      ValorAgente = SimularEntorno(eval_env, ag.policy, "Juega el Agente Entrenado", 1) 
    else:
      print("\n(primero debe juegar Humano)")
      ValorAgente = -1
    print("\n++ Juega Humano ++")
    j = 1
    time_step = eval_env.reset()  
    ob = time_step.observation.numpy()[0]
    print(" Ini: estado ", ob[0], "[", time_step, "]") 
  # muestra botones
  display(buttonR, button0, button1, output)

def on_button0_clicked(b):
  global j, eval_env
  # se toca botón de pedir nueva carta
  with output:
    time_step = eval_env.step( np.array(0, dtype=np.int32) )  
    ob = time_step.observation.numpy()[0]
    descAccion = "sale carta " + str( ob[1] )
    print(" #", j, ": ", descAccion, "-> estado ", ob[0], "[", time_step, "]")
    j = j + 1
    mostrarEstadoFinal( time_step )

def on_button1_clicked(b):
  global j, eval_env
  # se toca botón de finalizar partida
  with output:
    time_step = eval_env.step( np.array(1, dtype=np.int32) )
    ob = time_step.observation.numpy()[0]
    descAccion = "decide no pedir más cartas"
    print(" #", j, ": ", descAccion, "-> estado ", ob[0], "[", time_step, "]")
    mostrarEstadoFinal( time_step )

# define botones
buttonR = widgets.Button(description="Reiniciar Partida")
button0 = widgets.Button(description="Dame otra Carta")
button1 = widgets.Button(description="Finalizar!")
output = widgets.Output()
buttonR.on_click(on_buttonR_clicked)
button1.on_click(on_button1_clicked)
button0.on_click(on_button0_clicked)    

# comienza a jugar
j = 1     
ValorAgente = -1
on_buttonR_clicked(buttonR)
# Out:
# Button(description='Reiniciar Partida', style=ButtonStyle())
# Button(description='Dame otra Carta', style=ButtonStyle())
# Button(description='Finalizar!', style=ButtonStyle())
# Output()
# Button(description='Reiniciar Partida', style=ButtonStyle())
# Button(description='Dame otra Carta', style=ButtonStyle())
# Button(description='Finalizar!', style=ButtonStyle())
# Output()
# Button(description='Reiniciar Partida', style=ButtonStyle())
# Button(description='Dame otra Carta', style=ButtonStyle())
# Button(description='Finalizar!', style=ButtonStyle())
# Output()
# Button(description='Reiniciar Partida', style=ButtonStyle())
# Button(description='Dame otra Carta', style=ButtonStyle())
# Button(description='Finalizar!', style=ButtonStyle())
# Output()
