# %% [markdown]
# #Demo de Mars Explorer simulando la arquitectura Subsumption.
# - Objetivo : Explorar un planeta distante y en particular recolectar muestras de un cierto tipo de roca.
# - Problema: La localización de las rocas no se conoce, pero se sabe que ellas tienden a estar agrupadas en regiones cercanas

# %%
#@title Cargar Librerías

from random import randint
import copy

print("Librerías cargadas.")
# Out:
# Librerías cargadas.

# %%
#@title Definir Mapa al Azar
limiteMaximo = 10 #@param{"type":"integer"}
cantObstaculos = 30 #@param{"type":"integer"}
cantMuestras = 15 #@param{"type":"integer"}
if limiteMaximo<10:
  limiteMaximo = 10
if cantObstaculos<1:
  cantObstaculos = 1
if cantMuestras<1:
  cantMuestras = 1

# genera obstaculos
ObstaculosPos = []
for _ in range(30):
  ObstaculosPos.append(  [ randint(0, limiteMaximo),  randint(0, limiteMaximo) ] )
print("Obstaculos en ", ObstaculosPos)

# genera muestras
MuestrasPos = []
for _ in range(15):
  auxPos = [ randint(0, limiteMaximo),  randint(0, limiteMaximo) ]
  if auxPos not in ObstaculosPos:
    MuestrasPos.append( auxPos)
print("Muestras en ", MuestrasPos )
# Out:
# Obstaculos en  [[8, 1], [8, 3], [3, 7], [3, 7], [3, 8], [8, 10], [2, 9], [4, 4], [2, 4], [4, 4], [1, 9], [10, 1], [5, 5], [2, 7], [2, 4], [8, 9], [10, 5], [4, 3], [3, 0], [2, 9], [4, 1], [1, 0], [7, 5], [2, 1], [1, 6], [8, 2], [10, 6], [1, 5], [4, 8], [3, 4]]
# Muestras en  [[6, 10], [0, 9], [10, 2], [9, 3], [9, 6], [7, 2], [9, 2], [7, 2], [3, 9], [2, 0], [10, 9], [1, 2], [10, 4], [7, 8]]

# %%
#@title Definir clase MarsExplorer

POS_NADA = "-"
POS_BASE = "NAVE"
POS_MUESTRA = "MUESTRA"
POS_OBSTACULO = "OBSTACULO"

class MarsExplorer(object):

    def __init__(self, posInicial, limiteMaximo, obstaculosPos, muestrasPos):
      self.posActual = copy.deepcopy(posInicial)
      self.posBase = copy.deepcopy(posInicial)
      self.llevaMuestra = False
      self._limiteMaximo = limiteMaximo
      self._obstaculosPos = obstaculosPos
      self._muestrasPos = muestrasPos

    def determinaMov(self, posRegresar=None):
      # nueva posición
      nPos = copy.deepcopy(self.posActual)
      if posRegresar is None:
          # cambia posición al azar
          for i in range(len(nPos)):
            if (nPos[i]==0):
               nPos[i] += 1
            elif (nPos[i]==self._limiteMaximo):
              nPos[i] -= 1
            else:
              rnd = randint(-1, 1)
              if (i == 0) and (rnd==0):
                nPos[i] += 1
              else:
                nPos[i] += rnd
      else:
          # regresa a la pos indicada
          for i in range(len(nPos)):
            if (nPos[i]>0) and (nPos[i]<self._limiteMaximo):
              if posRegresar[i]>nPos[i]:
                nPos[i] += 1
              elif posRegresar[i]<nPos[i]:
                nPos[i] -= 1
      # devuelve nueva posición
      return nPos

    def distanciaBase(self, pos):
      # calcula distancia entre dos puntos
      dist = 0.0
      for p, b in zip(pos, self.posBase):
        dist += (p - b)**2
      return dist**0.5

    def evaluarPosicion(self, nPos):
      # determina si hay algo en la posicion usando random
      if self.distanciaBase(nPos)<1:
        # está en base
        return POS_BASE
      elif nPos in self._obstaculosPos:
        # hay obstaculo
        return POS_OBSTACULO
      elif nPos in self._muestrasPos:
        # hay muestra
        return POS_MUESTRA
      else:
        return POS_NADA

    def analizarMuestra(self, posNueva):
      # determina si es interesante
      # si la 1er posición es par
      return (randint(1, 2)==1)

    def tomarMuestra(self, pos):
      # toma la muestra
      self.llevaMuestra = True
      # elimina la muestra porque fue tomada
      self._muestrasPos.remove( pos )

    def dejarMuestra(self):
      # deja la muestra
      self.llevaMuestra = False

    def reglasC0(self, posNueva, posEval):
        ##C0 - Evitar obstáculos
        if posEval == POS_OBSTACULO:
          # determina nueva posición al azar
          # descarta posición (no la actualiza)
          return [True, False, None, "C0: Evita OBSTACULO"]
        else:
           return [False, False, None, None]

    def reglasC1(self, posNueva, posEval):
        ##C1 - Dejar muestras en la nave
        if self.llevaMuestra and (posEval == POS_BASE):
          # deja muestra
          self.dejarMuestra()
          return [True, True, None, "C1: Deja MUESTRA en NAVE"]
        else:
          return [False, False,  None, None]

    def reglasC2(self, posNueva, posEval):
        ##C2 - Llevar muestras a la nave
        if self.llevaMuestra and (posEval != POS_BASE):
          # determina nueva posición para regresar nave
          return [True, True, self.posBase, "C2: Llevando MUESTRA a NAVE"]
        else:
          return [False, False, None, None]

    def reglasC3y4(self, posNueva, posEval):
        ##C4 - Identificar muestras
        if not(self.llevaMuestra) and (posEval == POS_MUESTRA):
          # analiza la muestra
          detectaMuestraInt = self.analizarMuestra(posNueva)
          strDesc = "C4: Identifica MUESTRA ( interesante="+str(detectaMuestraInt)+")"
          # si interesante la toma, sino la descarta
          if detectaMuestraInt:
            ##C3 - Recolectar muestras
            strDesc = strDesc + " --> C3: Recolecta MUESTRA"
            # toma muestra
            self.tomarMuestra(posNueva)
            return [True, True, self.posBase, strDesc]
          else:
            return [True, True, None, strDesc]
        else:
          return [False, False,  None, None]

    def reglasC5(self, posNueva, posEval):
        ##C5 - Deambular (moverse al azar)
        # devuelve resultados
        return [True, True, None, "C5- DEAMBULAR"]


    def ejecutar(self, N):
      # define las regla a ejecutar
      reglaComportamiento = [self.reglasC0, self.reglasC1, self.reglasC2, self.reglasC3y4, self.reglasC5]
      # determina posición inicial
      posNueva = self.posBase
      posEval = self.evaluarPosicion(posNueva)
      print(0, "-- Comienza en NAVE ",  self.posBase, "")
      # ejecuta
      for i in range(1, N+1):
        # ejecuta la regla que corresponda
        for regla in reglaComportamiento:
          # ejecuta regla devolviendo:
          #   0: si se cumplieron las condiciones de la regla
          #   1: si se actualiza la posición actual
          #   2: la posición a regresara (si no es None)
          #   3: descripción de la regla
          resRegla = regla(posNueva, posEval)
          # si se ejecuta la regla
          if resRegla[0]:
            # si actualiza posición actual
            if resRegla[1]:
              # actualiza posición
              self.posActual = posNueva

            # determina nueva posición  (al azar o no)
            posNueva = self.determinaMov(resRegla[2])
            # analiza nueva posición
            posEval = self.evaluarPosicion(posNueva)
            # muestra mensaje regla
            if (len(resRegla)>3) and (resRegla[3] is None):
              strDesc = str(regla)
            else:
              strDesc = resRegla[3]
            print("#" +str(i), "--", self.posActual, "--", strDesc, "--> nuevaPos:", posNueva, "(", posEval, ")")
            break


print("clase MarsExplorer definida.")
# Out:
# clase MarsExplorer definida.

# %%
#@title Indicar cantidad de ciclos de Ejecución (N)
N = 250 #@param {"type":"integer"}
if N<5:
  N=5

# ejecuta
posIni = [5, 5]
me = MarsExplorer(posIni, limiteMaximo,
                  ObstaculosPos,
                  MuestrasPos)
me.ejecutar(N)
# Out:
# 0 -- Comienza en NAVE  [5, 5]
# #1 -- [5, 5] -- C5- DEAMBULAR --> nuevaPos: [4, 6] ( - )
# #2 -- [4, 6] -- C5- DEAMBULAR --> nuevaPos: [5, 6] ( - )
# #3 -- [5, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 5] ( - )
# #4 -- [6, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #5 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 7] ( - )
# #6 -- [6, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #7 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 6] ( - )
# #8 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #9 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #10 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( MUESTRA )
# #11 -- [9, 6] -- C4: Identifica MUESTRA ( interesante=True) --> C3: Recolecta MUESTRA --> nuevaPos: [8, 5] ( - )
# #12 -- [8, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [7, 5] ( OBSTACULO )
# #13 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [7, 4] ( - )
# #14 -- [7, 4] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [6, 5] ( - )
# #15 -- [6, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [5, 5] ( NAVE )
# #16 -- [5, 5] -- C1: Deja MUESTRA en NAVE --> nuevaPos: [4, 4] ( OBSTACULO )
# #17 -- [5, 5] -- C0: Evita OBSTACULO --> nuevaPos: [6, 4] ( - )
# #18 -- [6, 4] -- C5- DEAMBULAR --> nuevaPos: [5, 4] ( - )
# #19 -- [5, 4] -- C5- DEAMBULAR --> nuevaPos: [4, 3] ( OBSTACULO )
# #20 -- [5, 4] -- C0: Evita OBSTACULO --> nuevaPos: [4, 3] ( OBSTACULO )
# #21 -- [5, 4] -- C0: Evita OBSTACULO --> nuevaPos: [6, 3] ( - )
# #22 -- [6, 3] -- C5- DEAMBULAR --> nuevaPos: [5, 3] ( - )
# #23 -- [5, 3] -- C5- DEAMBULAR --> nuevaPos: [6, 2] ( - )
# #24 -- [6, 2] -- C5- DEAMBULAR --> nuevaPos: [7, 1] ( - )
# #25 -- [7, 1] -- C5- DEAMBULAR --> nuevaPos: [8, 2] ( OBSTACULO )
# #26 -- [7, 1] -- C0: Evita OBSTACULO --> nuevaPos: [8, 0] ( - )
# #27 -- [8, 0] -- C5- DEAMBULAR --> nuevaPos: [7, 1] ( - )
# #28 -- [7, 1] -- C5- DEAMBULAR --> nuevaPos: [6, 2] ( - )
# #29 -- [6, 2] -- C5- DEAMBULAR --> nuevaPos: [5, 3] ( - )
# #30 -- [5, 3] -- C5- DEAMBULAR --> nuevaPos: [4, 2] ( - )
# #31 -- [4, 2] -- C5- DEAMBULAR --> nuevaPos: [5, 3] ( - )
# #32 -- [5, 3] -- C5- DEAMBULAR --> nuevaPos: [6, 4] ( - )
# #33 -- [6, 4] -- C5- DEAMBULAR --> nuevaPos: [7, 5] ( OBSTACULO )
# #34 -- [6, 4] -- C0: Evita OBSTACULO --> nuevaPos: [5, 5] ( NAVE )
# #35 -- [5, 5] -- C5- DEAMBULAR --> nuevaPos: [4, 5] ( - )
# #36 -- [4, 5] -- C5- DEAMBULAR --> nuevaPos: [5, 6] ( - )
# #37 -- [5, 6] -- C5- DEAMBULAR --> nuevaPos: [4, 6] ( - )
# #38 -- [4, 6] -- C5- DEAMBULAR --> nuevaPos: [5, 6] ( - )
# #39 -- [5, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 5] ( - )
# #40 -- [6, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #41 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #42 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [9, 4] ( - )
# #43 -- [9, 4] -- C5- DEAMBULAR --> nuevaPos: [10, 3] ( - )
# #44 -- [10, 3] -- C5- DEAMBULAR --> nuevaPos: [9, 3] ( MUESTRA )
# #45 -- [9, 3] -- C4: Identifica MUESTRA ( interesante=True) --> C3: Recolecta MUESTRA --> nuevaPos: [8, 4] ( - )
# #46 -- [8, 4] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [7, 5] ( OBSTACULO )
# #47 -- [8, 4] -- C0: Evita OBSTACULO --> nuevaPos: [9, 4] ( - )
# #48 -- [9, 4] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [8, 5] ( - )
# #49 -- [8, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [7, 5] ( OBSTACULO )
# #50 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [9, 5] ( - )
# #51 -- [9, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [8, 5] ( - )
# #52 -- [8, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [7, 5] ( OBSTACULO )
# #53 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [7, 5] ( OBSTACULO )
# #54 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [7, 5] ( OBSTACULO )
# #55 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [7, 4] ( - )
# #56 -- [7, 4] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [6, 5] ( - )
# #57 -- [6, 5] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [5, 5] ( NAVE )
# #58 -- [5, 5] -- C1: Deja MUESTRA en NAVE --> nuevaPos: [6, 4] ( - )
# #59 -- [6, 4] -- C5- DEAMBULAR --> nuevaPos: [5, 4] ( - )
# #60 -- [5, 4] -- C5- DEAMBULAR --> nuevaPos: [6, 5] ( - )
# #61 -- [6, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #62 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 6] ( - )
# #63 -- [6, 6] -- C5- DEAMBULAR --> nuevaPos: [7, 7] ( - )
# #64 -- [7, 7] -- C5- DEAMBULAR --> nuevaPos: [8, 6] ( - )
# #65 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [7, 7] ( - )
# #66 -- [7, 7] -- C5- DEAMBULAR --> nuevaPos: [6, 7] ( - )
# #67 -- [6, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #68 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 5] ( - )
# #69 -- [6, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #70 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #71 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 4] ( - )
# #72 -- [7, 4] -- C5- DEAMBULAR --> nuevaPos: [6, 4] ( - )
# #73 -- [6, 4] -- C5- DEAMBULAR --> nuevaPos: [7, 5] ( OBSTACULO )
# #74 -- [6, 4] -- C0: Evita OBSTACULO --> nuevaPos: [7, 5] ( OBSTACULO )
# #75 -- [6, 4] -- C0: Evita OBSTACULO --> nuevaPos: [7, 5] ( OBSTACULO )
# #76 -- [6, 4] -- C0: Evita OBSTACULO --> nuevaPos: [7, 4] ( - )
# #77 -- [7, 4] -- C5- DEAMBULAR --> nuevaPos: [8, 4] ( - )
# #78 -- [8, 4] -- C5- DEAMBULAR --> nuevaPos: [9, 5] ( - )
# #79 -- [9, 5] -- C5- DEAMBULAR --> nuevaPos: [8, 6] ( - )
# #80 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #81 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #82 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #83 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [10, 6] ( OBSTACULO )
# #84 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [10, 6] ( OBSTACULO )
# #85 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [10, 6] ( OBSTACULO )
# #86 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [10, 6] ( OBSTACULO )
# #87 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [8, 6] ( - )
# #88 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #89 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [10, 6] ( OBSTACULO )
# #90 -- [9, 7] -- C0: Evita OBSTACULO --> nuevaPos: [8, 7] ( - )
# #91 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #92 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [10, 5] ( OBSTACULO )
# #93 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [8, 6] ( - )
# #94 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #95 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #96 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #97 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #98 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #99 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [8, 7] ( - )
# #100 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #101 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #102 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #103 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #104 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #105 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #106 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #107 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #108 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #109 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #110 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #111 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 10] ( OBSTACULO )
# #112 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [10, 8] ( - )
# #113 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #114 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [8, 7] ( - )
# #115 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #116 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [10, 6] ( OBSTACULO )
# #117 -- [9, 7] -- C0: Evita OBSTACULO --> nuevaPos: [8, 7] ( - )
# #118 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #119 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [6, 7] ( - )
# #120 -- [6, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 8] ( MUESTRA )
# #121 -- [7, 8] -- C4: Identifica MUESTRA ( interesante=False) --> nuevaPos: [8, 9] ( OBSTACULO )
# #122 -- [7, 8] -- C0: Evita OBSTACULO --> nuevaPos: [6, 7] ( - )
# #123 -- [6, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 8] ( MUESTRA )
# #124 -- [7, 8] -- C4: Identifica MUESTRA ( interesante=False) --> nuevaPos: [8, 9] ( OBSTACULO )
# #125 -- [7, 8] -- C0: Evita OBSTACULO --> nuevaPos: [8, 7] ( - )
# #126 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #127 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #128 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #129 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #130 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #131 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 10] ( OBSTACULO )
# #132 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [10, 10] ( - )
# #133 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #134 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #135 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #136 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #137 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #138 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #139 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #140 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #141 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #142 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [8, 9] ( OBSTACULO )
# #143 -- [9, 8] -- C0: Evita OBSTACULO --> nuevaPos: [8, 8] ( - )
# #144 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [7, 7] ( - )
# #145 -- [7, 7] -- C5- DEAMBULAR --> nuevaPos: [8, 7] ( - )
# #146 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #147 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 6] ( - )
# #148 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [7, 7] ( - )
# #149 -- [7, 7] -- C5- DEAMBULAR --> nuevaPos: [8, 7] ( - )
# #150 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #151 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #152 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 4] ( - )
# #153 -- [7, 4] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #154 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [7, 5] ( OBSTACULO )
# #155 -- [8, 5] -- C0: Evita OBSTACULO --> nuevaPos: [9, 6] ( - )
# #156 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [10, 5] ( OBSTACULO )
# #157 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [10, 7] ( - )
# #158 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #159 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #160 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #161 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [8, 8] ( - )
# #162 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #163 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #164 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #165 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #166 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #167 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #168 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #169 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #170 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #171 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #172 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #173 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 8] ( - )
# #174 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #175 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 9] ( OBSTACULO )
# #176 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [10, 9] ( - )
# #177 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 10] ( - )
# #178 -- [9, 10] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #179 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 10] ( - )
# #180 -- [9, 10] -- C5- DEAMBULAR --> nuevaPos: [8, 9] ( OBSTACULO )
# #181 -- [9, 10] -- C0: Evita OBSTACULO --> nuevaPos: [10, 9] ( - )
# #182 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #183 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 10] ( OBSTACULO )
# #184 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [8, 9] ( OBSTACULO )
# #185 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [10, 10] ( - )
# #186 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #187 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #188 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #189 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #190 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #191 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #192 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #193 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 9] ( OBSTACULO )
# #194 -- [9, 9] -- C0: Evita OBSTACULO --> nuevaPos: [10, 8] ( - )
# #195 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #196 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #197 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 10] ( - )
# #198 -- [9, 10] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #199 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #200 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #201 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #202 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #203 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 7] ( - )
# #204 -- [9, 7] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #205 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #206 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #207 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #208 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 6] ( - )
# #209 -- [8, 6] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #210 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #211 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 6] ( - )
# #212 -- [9, 6] -- C5- DEAMBULAR --> nuevaPos: [10, 6] ( OBSTACULO )
# #213 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [10, 6] ( OBSTACULO )
# #214 -- [9, 6] -- C0: Evita OBSTACULO --> nuevaPos: [8, 7] ( - )
# #215 -- [8, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #216 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #217 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #218 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 8] ( - )
# #219 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #220 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #221 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #222 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 8] ( - )
# #223 -- [10, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #224 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 9] ( - )
# #225 -- [10, 9] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #226 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [10, 7] ( - )
# #227 -- [10, 7] -- C5- DEAMBULAR --> nuevaPos: [9, 8] ( - )
# #228 -- [9, 8] -- C5- DEAMBULAR --> nuevaPos: [8, 8] ( - )
# #229 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #230 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [10, 10] ( - )
# #231 -- [10, 10] -- C5- DEAMBULAR --> nuevaPos: [9, 9] ( - )
# #232 -- [9, 9] -- C5- DEAMBULAR --> nuevaPos: [8, 8] ( - )
# #233 -- [8, 8] -- C5- DEAMBULAR --> nuevaPos: [7, 8] ( MUESTRA )
# #234 -- [7, 8] -- C4: Identifica MUESTRA ( interesante=True) --> C3: Recolecta MUESTRA --> nuevaPos: [6, 7] ( - )
# #235 -- [6, 7] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [5, 6] ( - )
# #236 -- [5, 6] -- C2: Llevando MUESTRA a NAVE --> nuevaPos: [5, 5] ( NAVE )
# #237 -- [5, 5] -- C1: Deja MUESTRA en NAVE --> nuevaPos: [4, 6] ( - )
# #238 -- [4, 6] -- C5- DEAMBULAR --> nuevaPos: [5, 7] ( - )
# #239 -- [5, 7] -- C5- DEAMBULAR --> nuevaPos: [6, 7] ( - )
# #240 -- [6, 7] -- C5- DEAMBULAR --> nuevaPos: [7, 6] ( - )
# #241 -- [7, 6] -- C5- DEAMBULAR --> nuevaPos: [8, 5] ( - )
# #242 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [9, 4] ( - )
# #243 -- [9, 4] -- C5- DEAMBULAR --> nuevaPos: [8, 4] ( - )
# #244 -- [8, 4] -- C5- DEAMBULAR --> nuevaPos: [9, 4] ( - )
# #245 -- [9, 4] -- C5- DEAMBULAR --> nuevaPos: [8, 3] ( OBSTACULO )
# #246 -- [9, 4] -- C0: Evita OBSTACULO --> nuevaPos: [10, 5] ( OBSTACULO )
# #247 -- [9, 4] -- C0: Evita OBSTACULO --> nuevaPos: [8, 5] ( - )
# #248 -- [8, 5] -- C5- DEAMBULAR --> nuevaPos: [9, 5] ( - )
# #249 -- [9, 5] -- C5- DEAMBULAR --> nuevaPos: [10, 6] ( OBSTACULO )
# #250 -- [9, 5] -- C0: Evita OBSTACULO --> nuevaPos: [10, 5] ( OBSTACULO )
